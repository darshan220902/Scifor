# %%
import pandas as pd

# %%
df=pd.read_csv('fatalities_isr_pse_conflict_2000_to_2023.csv')

# %%
df.head()
# Out:
#                                           name date_of_event   age  \
# 0  'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1         Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2             'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3             Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                 Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
#
#    citizenship     event_location event_location_district  \
# 0  Palestinian     Nur Shams R.C.                 Tulkarm
# 1  Palestinian     Nur Shams R.C.                 Tulkarm
# 2  Palestinian           Kfar Dan                   Jenin
# 3  Palestinian  'Aqbat Jaber R.C.                 Jericho
# 4  Palestinian         Jenin R.C.                   Jenin
#
#   event_location_region date_of_death gender took_part_in_the_hostilities  \
# 0             West Bank    2023-09-24      M                          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11124 entries, 0 to 11123
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          11124 non-null  object
#  1   date_of_event                 11124 non-null  object
#  2   age                           10995 non-null  float64
#  3   citizenship                   11124 non-null  object
#  4   event_location                11124 non-null  object
#  5   event_location_district       11124 non-null  object
#  6   event_location_region         11124 non-null  object
#  7   date_of_death                 11124 non-null  object
#  8   gender                        11104 non-null  object
#  9   took_part_in_the_hostilities  9694 non-null   object
#  10  place_of_residence            11056 non-null  object
#  11  place_of_residence_district   11056 non-null  object
# ...

# %%
df_new=df
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11124 entries, 0 to 11123
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          11124 non-null  object
#  1   date_of_event                 11124 non-null  object
#  2   age                           10995 non-null  float64
#  3   citizenship                   11124 non-null  object
#  4   event_location                11124 non-null  object
#  5   event_location_district       11124 non-null  object
#  6   event_location_region         11124 non-null  object
#  7   date_of_death                 11124 non-null  object
#  8   gender                        11104 non-null  object
#  9   took_part_in_the_hostilities  9694 non-null   object
#  10  place_of_residence            11056 non-null  object
#  11  place_of_residence_district   11056 non-null  object
# ...

# %%
df_new = df.drop(['ammunition', 'took_part_in_the_hostilities'], axis=1)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11124 entries, 0 to 11123
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         11124 non-null  object
#  1   date_of_event                11124 non-null  object
#  2   age                          10995 non-null  float64
#  3   citizenship                  11124 non-null  object
#  4   event_location               11124 non-null  object
#  5   event_location_district      11124 non-null  object
#  6   event_location_region        11124 non-null  object
#  7   date_of_death                11124 non-null  object
#  8   gender                       11104 non-null  object
#  9   place_of_residence           11056 non-null  object
#  10  place_of_residence_district  11056 non-null  object
#  11  type_of_injury               10833 non-null  object
#  12  killed_by                    11124 non-null  object
# ...

# %%
df_new.dropna(inplace=True)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10428 entries, 0 to 11122
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         10428 non-null  object
#  1   date_of_event                10428 non-null  object
#  2   age                          10428 non-null  float64
#  3   citizenship                  10428 non-null  object
#  4   event_location               10428 non-null  object
#  5   event_location_district      10428 non-null  object
#  6   event_location_region        10428 non-null  object
#  7   date_of_death                10428 non-null  object
#  8   gender                       10428 non-null  object
#  9   place_of_residence           10428 non-null  object
#  10  place_of_residence_district  10428 non-null  object
#  11  type_of_injury               10428 non-null  object
#  12  killed_by                    10428 non-null  object
# ...

# %%
df_new.head()
# Out:
#                                           name date_of_event   age  \
# 0  'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1         Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2             'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3             Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                 Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
#
#    citizenship     event_location event_location_district  \
# 0  Palestinian     Nur Shams R.C.                 Tulkarm
# 1  Palestinian     Nur Shams R.C.                 Tulkarm
# 2  Palestinian           Kfar Dan                   Jenin
# 3  Palestinian  'Aqbat Jaber R.C.                 Jericho
# 4  Palestinian         Jenin R.C.                   Jenin
#
#   event_location_region date_of_death gender place_of_residence  \
# 0             West Bank    2023-09-24      M     Nur Shams R.C.
# 1             West Bank    2023-09-24      M     Nur Shams R.C.
# ...

# %%
df_new['date_of_death']=pd.to_datetime(df['date_of_death'])
df_new['date_of_event']=pd.to_datetime(df['date_of_event'])

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10428 entries, 0 to 11122
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         10428 non-null  object
#  1   date_of_event                10428 non-null  datetime64[ns]
#  2   age                          10428 non-null  float64
#  3   citizenship                  10428 non-null  object
#  4   event_location               10428 non-null  object
#  5   event_location_district      10428 non-null  object
#  6   event_location_region        10428 non-null  object
#  7   date_of_death                10428 non-null  datetime64[ns]
#  8   gender                       10428 non-null  object
#  9   place_of_residence           10428 non-null  object
#  10  place_of_residence_district  10428 non-null  object
#  11  type_of_injury               10428 non-null  object
# ...

# %%
df_new.to_csv('Conflict.csv')
